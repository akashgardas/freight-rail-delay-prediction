# %% [markdown]
# <a href="https://colab.research.google.com/github/RishithaSrija/freight-rail-delay-prediction/blob/data-analysis/notebooks/Wagon_Position_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Wagon_Position
# **WAGON_POSITION** —
# Tracks the last-known GPS position of an individual wagon at a given timestamp.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##Load and Inspect data

# %%
import chardet
with open("/content/drive/MyDrive/Mini_project(3-2)/WAGON_POSITION.csv","rb") as f:
  res=chardet.detect(f.read(100_000))
  print(res)
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
path = '/content/drive/MyDrive/Mini_project(3-2)/WAGON_POSITION.csv'
df = pd.read_csv(path, encoding='ascii')
df.head(20)
# Out:
#     IDWAGON_POSITION  IDWAGON           DateH_position   Latitude  Longitude  \
# 0                  1       37  2020-11-20 15:11:13.000  51.371796   4.282741
# 1                  2      247  2020-11-20 14:05:59.000  48.094210  11.809816
# 2                  3      247  2020-11-20 14:11:13.000  48.118225  11.699616
# 3                  4      247  2020-11-20 14:16:35.000  48.122265  11.595469
# 4                  5      247  2020-11-20 14:21:48.000  48.136540  11.526796
# 5                  6      247  2020-11-20 14:27:01.000  48.144707  11.507050
# 6                  7      247  2020-11-20 14:28:24.000  48.145180  11.504237
# 7                  8      247  2020-11-20 14:39:11.000  48.145153  11.503295
# 8                  9      247  2020-11-20 14:49:22.000  48.145153  11.503373
# 9                 10      247  2020-11-20 14:58:24.000  48.145008  11.503424
# 10                11      247  2020-11-20 15:18:37.000  48.145200  11.500172
# ...

# %%
#shape
df.shape
# Out:
# (1048574, 8)

# %%
#data types
df.dtypes
# Out:
# IDWAGON_POSITION      int64
# IDWAGON               int64
# DateH_position       object
# Latitude            float64
# Longitude           float64
# Application_GPS     float64
# Qualifiant          float64
# Etat_position       float64
# dtype: object

# %%
#columns
df.columns
# Out:
# Index(['IDWAGON_POSITION', 'IDWAGON', 'DateH_position', 'Latitude',
#        'Longitude', 'Application_GPS', 'Qualifiant', 'Etat_position'],
#       dtype='object')

# %%
# Unique values in each column
col_unique_counts = {}
for col in df.columns:
    col_unique_counts[col] = df[col].nunique()

col_unique_counts
# Out:
# {'IDWAGON_POSITION': 1048574,
#  'IDWAGON': 323,
#  'DateH_position': 522908,
#  'Latitude': 336590,
#  'Longitude': 486488,
#  'Application_GPS': 0,
#  'Qualifiant': 0,
#  'Etat_position': 0}
