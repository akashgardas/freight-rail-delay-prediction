# %% [markdown]
# <a href="https://colab.research.google.com/github/RishithaSrija/freight-rail-delay-prediction/blob/data-analysis/notebooks/Wagon_Capacity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Wagon Capacity Data Analysis
#
# **WAGON_CAPACITY** — Defines the loading capacity specifications (C, N, P ratings) for each wagon model.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##Load and Inspect data

# %%
import chardet
with open("/content/drive/MyDrive/Mini_project(3-2)/WAGON_CAPACITE.csv","rb") as f:
  res=chardet.detect(f.read(100_000))
  print(res)
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
path = '/content/drive/MyDrive/Mini_project(3-2)/WAGON_CAPACITE.csv'
df = pd.read_csv(path, encoding='ascii')
df.head(20)
# Out:
#     IDWAGON_CAPACITE  IDUtilisateur_creation           DateH_creation  \
# 0                  3                       5  2019-04-19 16:01:25.487
# 1                  4                      39  2019-05-03 12:18:44.623
# 2                  5                      39  2019-05-03 12:20:27.203
# 3                  6                      39  2019-05-08 15:33:23.643
# 4                  7                      39  2019-05-08 15:37:01.187
# 5                  8                      39  2019-05-08 15:37:01.207
# 6                  9                      39  2019-05-08 15:37:01.227
# 7                 10                      39  2019-05-13 15:19:23.843
# 8                 11                      39  2019-05-13 15:19:23.883
# 9                 12                      39  2019-05-13 15:19:23.923
# 10                13                      39  2019-05-13 15:19:23.953
# 11                14                      39  2019-05-13 15:19:23.993
# ...

# %%
#shape
df.shape
# Out:
# (29, 10)

# %%
#data types
df.dtypes
# Out:
# IDWAGON_CAPACITE            int64
# IDUtilisateur_creation      int64
# DateH_creation             object
# IDUtilisateur_maj         float64
# DateH_maj                 float64
# IDWAGON_MODELE              int64
# Code_pays                  object
# Capacite_C                float64
# Capacite_N                float64
# Capacite_P                float64
# dtype: object

# %%
#Null values
df.isna().sum()
# Out:
# IDWAGON_CAPACITE           0
# IDUtilisateur_creation     0
# DateH_creation             0
# IDUtilisateur_maj         29
# DateH_maj                 29
# IDWAGON_MODELE             0
# Code_pays                  7
# Capacite_C                23
# Capacite_N                27
# Capacite_P                 2
# dtype: int64

# %%
#columns
df.columns
# Out:
# Index(['IDWAGON_CAPACITE', 'IDUtilisateur_creation', 'DateH_creation',
#        'IDUtilisateur_maj', 'DateH_maj', 'IDWAGON_MODELE', 'Code_pays',
#        'Capacite_C', 'Capacite_N', 'Capacite_P'],
#       dtype='object')

# %%
# Unique values in each column
col_unique_counts = {}
for col in df.columns:
    col_unique_counts[col] = df[col].nunique()

col_unique_counts
# Out:
# {'IDWAGON_CAPACITE': 29,
#  'IDUtilisateur_creation': 4,
#  'DateH_creation': 24,
#  'IDUtilisateur_maj': 0,
#  'DateH_maj': 0,
#  'IDWAGON_MODELE': 7,
#  'Code_pays': 13,
#  'Capacite_C': 2,
#  'Capacite_N': 1,
#  'Capacite_P': 3}

# %%
df.Code_pays.value_counts()
# Out:
# Code_pays
# CH    5
# BE    3
# DE    3
# SE    2
# NL    1
# GB    1
# DK    1
# NO    1
# IT    1
# PL    1
# AT    1
# LU    1
# FR    1
# Name: count, dtype: int64
