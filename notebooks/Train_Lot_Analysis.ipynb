# %% [markdown]
# <a href="https://colab.research.google.com/github/akashgardas/freight-rail-delay-prediction/blob/data-analysis/notebooks/Train_Lot_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train Lot data analysis

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load and Inspect data

# %%
import chardet
path = '/content/drive/MyDrive/CVR College/Mini Project/data/TRAIN_LOT.csv'
with open(path, "rb") as f:
    result = chardet.detect(f.read(100_000))  # sample first 100k bytes

print(result)
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
# Load
df = pd.read_csv(path, encoding='ISO-8859-1')
df.head()
# Out:
#    IDTRAIN_LOT  IDTRAIN  Lot_num  DHR_Arrivee  DHT_Arrivee Nom_lot  \
# 0          255      255        1          NaN          NaN     NaN
# 1          256      256        1          NaN          NaN     NaN
# 2          258      258        1          NaN          NaN     NaN
# 3          259      259        1          NaN          NaN     NaN
# 4          260      260        1          NaN          NaN     NaN
#
#   Commentaire  Distance  Poids_CO2  IDSOCIETE_Expediteur  ...  Status  \
# 0         NaN        99          0                   688  ...    1000
# 1         NaN        99          0                   688  ...     100
# 2         NaN        99          0                   688  ...     100
# 3         NaN        99          0                   688  ...     100
# 4         NaN        99          0                   688  ...     100
#
#    Longueur_totale  Voie_categorie  Voie_vitesse  Motif_suppression  \
# 0            390.0             NaN           NaN                NaN
# ...

# %%
df.shape
# Out:
# (14692, 45)

# %%
df.columns
# Out:
# Index(['IDTRAIN_LOT', 'IDTRAIN', 'Lot_num', 'DHR_Arrivee', 'DHT_Arrivee',
#        'Nom_lot', 'Commentaire', 'Distance', 'Poids_CO2',
#        'IDSOCIETE_Expediteur', 'IDSOCIETE_Destinataire', 'IDJALON_Origine',
#        'IDJALON_Destination', 'Surbooking', 'Objectif_CA', 'Objectif_TEU',
#        'DHT_Depart', 'DHR_Depart', 'H_Depart_ecart', 'H_Arrivee_ecart',
#        'IDUtilisateur_creation', 'DateH_creation', 'IDUtilisateur_maj',
#        'DateH_maj', 'Ref_Expediteur', 'Ref_Destinataire', 'Train_Position',
#        'Incoterm', 'Num_LDV', 'Objectif_T', 'Objectif_UTI', 'Nbre_TEU',
#        'Capacite_TEU', 'Nbre_UTI', 'Poids_total', 'Status', 'Longueur_totale',
#        'Voie_categorie', 'Voie_vitesse', 'Motif_suppression',
#        'DateH_suppression', 'IDSOCIETE_Client', 'DateH_info_fournisseur',
#        'Responsable_annulation', 'Top_reservation_interdite'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14692 entries, 0 to 14691
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   IDTRAIN_LOT                14692 non-null  int64
#  1   IDTRAIN                    14692 non-null  int64
#  2   Lot_num                    14692 non-null  int64
#  3   DHR_Arrivee                0 non-null      float64
#  4   DHT_Arrivee                0 non-null      float64
#  5   Nom_lot                    1800 non-null   object
#  6   Commentaire                498 non-null    object
#  7   Distance                   14692 non-null  int64
#  8   Poids_CO2                  14692 non-null  int64
#  9   IDSOCIETE_Expediteur       14692 non-null  int64
#  10  IDSOCIETE_Destinataire     14692 non-null  int64
#  11  IDJALON_Origine            14692 non-null  int64
#  12  IDJALON_Destination        14692 non-null  int64
# ...

# %%
# Missing values
df.isna().sum()
# Out:
# IDTRAIN_LOT                      0
# IDTRAIN                          0
# Lot_num                          0
# DHR_Arrivee                  14692
# DHT_Arrivee                  14692
# Nom_lot                      12892
# Commentaire                  14194
# Distance                         0
# Poids_CO2                        0
# IDSOCIETE_Expediteur             0
# IDSOCIETE_Destinataire           0
# IDJALON_Origine                  0
# IDJALON_Destination              0
# Surbooking                       0
# Objectif_CA                      0
# Objectif_TEU                     0
# DHT_Depart                   14692
# DHR_Depart                   14692
# H_Depart_ecart                   0
# H_Arrivee_ecart                  0
# IDUtilisateur_creation           0
# DateH_creation                   0
# IDUtilisateur_maj                0
# DateH_maj                     4079
# Ref_Expediteur               13279
# Ref_Destinataire             12859
# Train_Position                   0
# ...
