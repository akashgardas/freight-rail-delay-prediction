# %% [markdown]
# <a href="https://colab.research.google.com/github/akashgardas/freight-rail-delay-prediction/blob/data-analysis/notebooks/Incident_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load & Inspect Data

# %%
import chardet
with open("/content/drive/MyDrive/Project/Datasets/INCIDENTS.csv", "rb") as f:
    result = chardet.detect(f.read(1000_000))  # sample first 100k bytes

print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.7293068993579889, 'language': ''}

# %%
path = '/content/drive/MyDrive/Project/Datasets/INCIDENTS.csv'
df = pd.read_csv(path, encoding='Windows-1252')
df.head()
# Out:
#    IDINCIDENT    Type_incident  IDINCIDENT_Pere  IDUtilisateur_creation  \
# 0         201       CORDON_TIR              0.0                      57
# 1         202         WAG. DIF            201.0                      57
# 2         203         WAG. DIF              0.0                      57
# 3         204         WAG. DIF              0.0                      31
# 4         205  UTI_MAL_CHARGEE            204.0                      31
#
#             DateH_creation  IDUtilisateur_maj                DateH_maj  \
# 0  2020-01-02 23:18:00.000               87.0  2020-03-10 14:48:34.290
# 1  2020-01-02 23:20:00.000               57.0  2020-01-02 23:28:38.460
# 2  2020-01-06 10:45:00.000               57.0  2020-01-13 07:12:50.120
# 3  2020-01-07 15:12:01.000               57.0  2020-01-13 07:12:28.630
# 4  2020-01-07 15:18:00.000               57.0  2020-01-07 18:00:49.150
#
#             DateH_incident      Lieu  Num_incident  \
# ...

# %%
# Shape
df.shape
# Out:
# (5875, 17)

# %%
# Dtypes
df.dtypes
# Out:
# IDINCIDENT                  int64
# Type_incident              object
# IDINCIDENT_Pere           float64
# IDUtilisateur_creation      int64
# DateH_creation             object
# IDUtilisateur_maj         float64
# DateH_maj                  object
# DateH_incident             object
# Lieu                       object
# Num_incident                int64
# Commentaire                object
# Statut                    float64
# Gravite                   float64
# Motif_client               object
# IDGARE                    float64
# Statut_commercial         float64
# Statut_financier          float64
# dtype: object

# %%
# Missing values
df.isna().sum()
# Out:
# IDINCIDENT                   0
# Type_incident                0
# IDINCIDENT_Pere            279
# IDUtilisateur_creation       0
# DateH_creation               0
# IDUtilisateur_maj           14
# DateH_maj                   14
# DateH_incident               0
# Lieu                      1427
# Num_incident                 0
# Commentaire               1943
# Statut                      25
# Gravite                     25
# Motif_client               109
# IDGARE                    4535
# Statut_commercial          872
# Statut_financier           872
# dtype: int64

# %%
# Missing values
df.isna().sum()
# Out:
# IDINCIDENT                   0
# Type_incident                0
# IDINCIDENT_Pere            279
# IDUtilisateur_creation       0
# DateH_creation               0
# IDUtilisateur_maj           14
# DateH_maj                   14
# DateH_incident               0
# Lieu                      1427
# Num_incident                 0
# Commentaire               1943
# Statut                      25
# Gravite                     25
# Motif_client               109
# IDGARE                    4535
# Statut_commercial          872
# Statut_financier           872
# dtype: int64

# %%
# Columns
df.columns
# Out:
# Index(['IDINCIDENT', 'Type_incident', 'IDINCIDENT_Pere',
#        'IDUtilisateur_creation', 'DateH_creation', 'IDUtilisateur_maj',
#        'DateH_maj', 'DateH_incident', 'Lieu', 'Num_incident', 'Commentaire',
#        'Statut', 'Gravite', 'Motif_client', 'IDGARE', 'Statut_commercial',
#        'Statut_financier'],
#       dtype='object')

# %%
# Unique values in each column
col_unique_counts = {}
for col in df.columns:
    col_unique_counts[col] = df[col].nunique()

col_unique_counts
# Out:
# {'IDINCIDENT': 5875,
#  'Type_incident': 152,
#  'IDINCIDENT_Pere': 290,
#  'IDUtilisateur_creation': 20,
#  'DateH_creation': 5853,
#  'IDUtilisateur_maj': 22,
#  'DateH_maj': 5856,
#  'DateH_incident': 5469,
#  'Lieu': 431,
#  'Num_incident': 5875,
#  'Commentaire': 3654,
#  'Statut': 3,
#  'Gravite': 6,
#  'Motif_client': 148,
#  'IDGARE': 83,
#  'Statut_commercial': 5,
#  'Statut_financier': 5}
