# %% [markdown]
# <a href="https://colab.research.google.com/github/akashgardas/freight-rail-delay-prediction/blob/data-analysis/notebooks/Train_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train Analysis

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load and Inspect Dataset

# %%
import chardet

with open("/content/drive/MyDrive/CVR College/Mini Project/data/STATION_GARE.csv", "rb") as f:
    result = chardet.detect(f.read(100_000))  # sample first 100k bytes

print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.7293868, 'language': ''}

# %%
# Load
path = '/content/drive/MyDrive/CVR College/Mini Project/data/TRAIN.csv'
df = pd.read_csv(path, encoding='ISO-8859-1')
df.head()
# Out:
#    IDTRAIN Train_num  IDRELATION Sens  IDCONTACT_Responsable  \
# 0      255     42951        2011    A                    NaN
# 1      256     42951        2011    A                    NaN
# 2      258     42951        2011    A                    NaN
# 3      259     42951        2011    A                    NaN
# 4      260     42951        2011    A                    NaN
#
#   Motif_suppression  IDTRAINREF_JOUR  IDUtilisateur_creation  \
# 0               NaN             5047                       5
# 1  Période de tests             5047                       5
# 2  Période de tests             5047                       5
# 3  Période de tests             5070                       5
# 4  Période de tests             5070                       5
#
#             DateH_creation  IDUtilisateur_maj                DateH_maj  IDATE  \
# 0  2019-02-25 09:57:57.000                 38  2021-02-01 16:24:38.510      7
# ...

# %%
# Shape
df.shape
# Out:
# (14215, 19)

# %%
# Columns
df.columns
# Out:
# Index(['IDTRAIN', 'Train_num', 'IDRELATION', 'Sens', 'IDCONTACT_Responsable',
#        'Motif_suppression', 'IDTRAINREF_JOUR', 'IDUtilisateur_creation',
#        'DateH_creation', 'IDUtilisateur_maj', 'DateH_maj', 'IDATE',
#        'Commentaire', 'Poids_maxi', 'Longueur_maxi', 'DateH_suppression',
#        'IDSOCIETE_suppression', 'IDTRAIN_Parent', 'Generer_Orfeus'],
#       dtype='object')

# %%
# Dtypes
df.dtypes
# Out:
# IDTRAIN                     int64
# Train_num                  object
# IDRELATION                  int64
# Sens                       object
# IDCONTACT_Responsable     float64
# Motif_suppression          object
# IDTRAINREF_JOUR             int64
# IDUtilisateur_creation      int64
# DateH_creation             object
# IDUtilisateur_maj           int64
# DateH_maj                  object
# IDATE                       int64
# Commentaire                object
# Poids_maxi                  int64
# Longueur_maxi               int64
# DateH_suppression          object
# IDSOCIETE_suppression     float64
# IDTRAIN_Parent            float64
# Generer_Orfeus              int64
# dtype: object

# %%
# Missing values
df.isnull().sum()
# Out:
# IDTRAIN                       0
# Train_num                     0
# IDRELATION                    0
# Sens                          0
# IDCONTACT_Responsable      2380
# Motif_suppression          8970
# IDTRAINREF_JOUR               0
# IDUtilisateur_creation        0
# DateH_creation                0
# IDUtilisateur_maj             0
# DateH_maj                  3711
# IDATE                         0
# Commentaire                9777
# Poids_maxi                    0
# Longueur_maxi                 0
# DateH_suppression          8921
# IDSOCIETE_suppression     13895
# IDTRAIN_Parent            14076
# Generer_Orfeus                0
# dtype: int64
